# %%
import arnielib as a
from importlib import reload

# %%
a.serial_ports()
# Out:
# ['COM6', 'COM18']

# %%
ar = a.connect()
# Out:
# ERROR: Couldn't close the port.
# Msg: Arnie's stationary touch probe
# Rev. 1.0, 11/20/2019
#
# ERROR: Couldn't close the port.
# Msg: start
# echo:Marlin 1.1.8
#
# echo: Last Updated: 2017-12-25 12:00 | Author: (none, default config)
# echo:Compiled: Dec 22 2019
# echo: Free Memory: 5437  PlannerBufferBytes: 1232
# echo:Hardcoded Default Settings Loaded
# echo:  G21    ; Units in mm
#
# echo:Filament settings: Disabled
# echo:  M200 D3.00
# echo:  M200 D0
# echo:Steps per unit:
# echo:  M92 X20.00 Y20.00 Z25.00 E500.00
# echo:Maximum feedrates (units/s):
# echo:  M203 X2000.00 Y2000.00 Z4000.00 E25.00
# echo:Maximum Acceleration (units/s2):
# echo:  M201 X10000 Y10000 Z1000 E10000
# echo:Acceleration (units/s2): P<print_accel> R<retract_accel> T<travel_accel>
# echo:  M204 P500.00 R10000.00 T500.00
# echo:Advanced: S<min_feedrate> T<min_travel_feedrate> B<min_segment_time_us> X<max_xy_jerk> Z<max_z_jerk> E<max_e_jerk>
# echo:  M205 S0.00 T0.00 B20000 X2.00 Y2.00 Z2.00 E5.00
# ...

# %%
a.get_tool(ar, type="mobile_probe")
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ERROR: Couldn't close the port.
# Msg: Arnie's mobile touch probe
# Rev.

# %%
a.calc_slot_center(ar, 0, 0)
# Out:
# [93.54499999999999, 65.7]

# %%
ar.params["slots"][0][0]
# Out:
# {'LB': [18.839999999999996, 120.65],
#  'LT': [19.54, 10.05],
#  'RB': [167.54999999999998, 121.35],
#  'RT': [168.54999999999998, 10.150000000000002],
#  'floor_z': 604.4}

# %%
ar.params
# Out:
# {'flower_height': 22.799999999999997,
#  'height_n': 4,
#  'plank_width': 7.900000000000002,
#  'slot_height': 111.8,
#  'slot_width': 148.79999999999998,
#  'slots': [[{'LB': [18.839999999999996, 120.65],
#     'LT': [19.54, 10.05],
#     'RB': [167.54999999999998, 121.35],
#     'RT': [168.54999999999998, 10.150000000000002],
#     'floor_z': 604.4},
#    {'LB': [18.04, 229.75],
#     'LT': [18.839999999999996, 120.65],
#     'RB': [166.75, 230.25],
#     'RT': [167.54999999999998, 121.35],
#     'floor_z': 604.4},
#    {'LB': [17.64, 340.45],
#     'LT': [18.04, 229.75],
#     'RB': [166.35, 341.45],
#     'RT': [166.75, 230.25],
#     'floor_z': 604.4},
#    {'LB': [17.64, 452.25],
#     'LT': [17.64, 340.45],
#     'RB': [166.35, 453.25],
#     'RT': [166.35, 341.45],
#     'floor_z': 604.4}],
#   [{'LB': [167.95000000000002, 122.15],
#     'LT': [168.95000000000002, 10.950000000000003],
#     'RB': [316.36, 122.35],
#     'RT': [317.36, 11.150000000000002],
# ...

# %%
reload(a)
# Out:
# <module 'arnielib' from 'C:\\Users\\sergiispam\\Dropbox\\workspace\\arnielib\\arnielib.py'>

# %%
a.calibrate_mobile_probe_tip(ar, x_n=0, y_n=0)
# Out:
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:240.76 Y:66.70 Z:0'
# MESSAGE: '.00 E:0.00 Count X:4815 Y:1334 Z:0\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# Mobile touch probe response: 0
#
# MESSAGE: 'X:93.54 Y:65.70 Z:464.40 E:0.00 Count X:1871 Y:1314 Z:11610\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# Mobile touch probe response: 0
#
# MESSAGE: 'X:93.54 Y:65.70 Z:472.50 E:0.00 Count X:1871 Y:1314 Z:11813\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# Mobile touch probe response: 0
#
# MESSAGE: 'X:93.54 Y:65.70 Z:480.60 E:0.00 Count X:1871 Y:1314 Z:12015\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# Mobile touch probe response: 0
#
# MESSAGE: 'X:93.54 Y:65.70 Z:488.70 E:0.00 Count X:1871 Y:1314 Z:12218\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ...

# %%
ar.move_delta(dz=-100)
# Out:
# MESSAGE: 'X:91.59 Y:66.60 Z:491.10 E:0.00 Count X:1832 Y:1332 Z:12278\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
a.calibrate_mobile_probe_rack(robot=ar, x_n=1, y_n=0)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:242.66 Y:66.65 Z:502.10 E:0.00 Count X:4853 Y:1333 Z:12553\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:250.76 Y:66.65 Z:502.10 E:0.00 Count X:5015 Y:1333 Z:12553\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:258.86 Y:66.65 Z:502.10 E:0.00 Count X:5177 Y:1333 Z:12553\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:266.96 Y:66.65 Z:502.10 E:0.00 Count X:5339 Y:1333 Z:12553\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 1
#
# MESSAGE: 'X:275.06 Y:66.65 Z:502.10 E:0.00 Count X:5501 Y:1333 Z:12553\nok\n'
# Mobile touch probe response: 1
#
# MESSAGE: 'X:275.06 Y:66.65 Z:502.10 E:0.00 Count X:5501 Y:1333 Z:12553\nok\n'
# MESSAGE: 'ok\n'
# ...

# %%
ar.return_tool()
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'o'
# MESSAGE: 'k\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: process'
# MESSAGE: 'ing\n'
# MESSAGE: 'X:240.76 Y:66.70 Z:0.00 E:0.00 Count X:4815 Y:1334 Z:0\nok\n'

# %%
# Picking up tool again for calibration of the remaining slots
a.get_tool(ar, type="mobile_probe")
a.calibrate_mobile_probe_tip(ar, x_n=0, y_n=0)
# Out:
# MESSAGE: 'X:485.20 Y:131.25 Z:10.00 E:0.00 Count X:38816 Y:10500 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy'
# MESSAGE: ': processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'ech'
# MESSAGE: 'o:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:485.20 Y:131.25 Z:10.00 E:0.00 Count X:38816 Y:10500 Z:800\nok\n'
# ERROR: Couldn't close the port.
# Msg: Arnie's mobile touch probe
# Rev. 1.01, 11/27/2019
#
# MESSAGE: 'X:485.20 Y:131.25 Z:10.00 E:0.00 Count X:38816 Y:10500 Z:800\nok\n'
# MESSAGE: 'ok\n'
# ...

# %%
ar.move(z=300)
a.calibrate_pipettor(robot=ar, x_n=2, y_n=0, volume=1000, pipettor_type='single')
#a.calibrate_pipettor(robot=ar, x_n=3, y_n=0, volume=200, pipettor_type='single')
#a.calibrate_pipettor(robot=ar, x_n=4, y_n=0, volume=20, pipettor_type='single')
#a.calibrate_mobile_gripper(robot=ar, x_n=5, y_n=3)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing'
# MESSAGE: '\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing'
# MESSAGE: '\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:0.00 Y:0.00 Z:0.00 E:0.00 Count X:0 Y:0 Z:0\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'X:318.05 Y:11.85 Z:449.50 E:0.00 Count X:6361 Y:237 Z:11238\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:392.45 Y:11.85 Z:449.50 E:0.00 Count X:7849 Y:237 Z:11238\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:392.45 Y:19.95 Z:449.50 E:0.00 Count X:7849 Y:399 Z:11238\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:392.45 Y:28.05 Z:449.50 E:0.00 Count X:7849 Y:561 Z:11238\nok\n'
# MESSAGE: 'ok\n'
# ...

# %%
ar.move(z=3000)
a.calibrate_tip_tray(robot=ar, x_n=0, y_n=2, tray_volume=1000)
a.calibrate_tip_tray(robot=ar, x_n=1, y_n=2, tray_volume=200)
a.calibrate_tip_tray(robot=ar, x_n=2, y_n=2, tray_volume=20)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: pr'
# MESSAGE: 'ocessing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo'
# MESSAGE: ':busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: process'
# MESSAGE: 'ing\n'
# MESSAGE: 'X:1761.79 Y:788.51 Z:10.00 E:0.00 Count X:140943 Y:63081 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:138.04 Y:459.64 Z:5351.50 E:0.00 Count X:11043 Y:36771 Z:428120\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:138.04 Y:469.64 Z:5351.50 E:0.00 Count X:11043 Y:37571 Z:428120\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# ...

# %%
ar.move(z=3000)
a.calibrate_rack(robot=ar, x_n=2, y_n=3, rack_type='eppendorf')
a.calibrate_rack(robot=ar, x_n=1, y_n=3, rack_type='magnetic_eppendorf')
a.calibrate_rack(robot=ar, x_n=3, y_n=3, rack_type='50_ml')
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:bus'
# MESSAGE: 'y: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: proce'
# MESSAGE: 'ssing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:778.72 Y:572.95 Z:10.00 E:0.00 Count X:62298 Y:45836 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 0
#
# MESSAGE: 'X:730.10 Y:681.86 Z:5094.00 E:0.00 Count X:58408 Y:54549 Z:407520\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Mobile touch probe response: 1
#
# MESSAGE: 'X:730.10 Y:691.86 Z:5094.00 E:0.00 Count X:58408 Y:55349 Z:407520\nok\n'
# Mobile touch probe response: 1
#
# MESSAGE: 'X:730.10 Y:691.86 Z:5094.00 E:0.00 Count X:58408 Y:55349 Z:407520\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ...

# %%
ar.return_tool()
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:240.76 Y:66.70 Z:0.00 E:0.00 Cou'
# MESSAGE: 'nt X:4815 Y:1334 Z:0\nok\n'

# %%
reload(a)
# Out:
# <module 'arnielib' from 'C:\\Users\\sergiispam\\Dropbox\\workspace\\arnielib\\arnielib.py'>

# %%
a.get_tool(ar, type="pipettor", subtype="single", volume=1000, z_dest_delta=-2)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ERROR: Couldn't close the port.
# Msg:
# Grbl Eh Servo 0.9j ['$' for he
# [Caution: Unlocked]
# ok
# ok
# error: Not idle
#
# <Run,MPos:-0.440,0.000,0.000,WPos:-0.440,0.000,0.000>
# ok
#
# <Run,MPos:-1.460,0.000,0.000,WPos:-1.460,0.000,0.000>
# ok
#
# <Run,MPos:-2.440,0.000,0.000,WPos:-2.440,0.000,0.000>
# ok
#
# <Run,MPos:-3.480,0.000,0.000,WPos:-3.480,0.000,0.000>
# ok
#
# <Run,MPos:-4.520,0.000,0.000,WPos:-4.520,0.000,0.000>
# ok
#
# <Idle,MPos:-5.000,0.000,0.000,WPos:-5.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000,WP
# os:-1.000,0.000,0.000>
# ok
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok

# %%
ar.move(z=1)
# Out:
# MESSAGE: 'ok\n'

# %%
# Calibrating against stalagmite
a.calibrate_pipettor_tip(robot=ar, x_n=0, y_n=0)
# Out:
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:389.2'
# MESSAGE: '0 Y:66.60 Z:0.00 E:0.00 Count X:7784 Y:1332 Z:0\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Floor_z height:
# 604.4
# 180
# 1.0
# 414.4
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:93.54 Y:65.70 Z:414.40 E:0.00 Count X:1871 Y:1314 Z:10360\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:93.54 Y:65.70 Z:422.50 E:0.00 Count X:1871 Y:1314 Z:10563\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:93.54 Y:65.70 Z:430.60 E:0.00 Count X:1871 Y:1314 Z:10765\nok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:93.54 Y:65.70 Z:430.60 E:0.00 Count X:1871 Y:1314 Z:10765\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:93.54 Y:65.70 Z:427.90 E:0.00 Count X:1871 Y:1314 Z:10698\nok\n'
# MESSAGE: 'ok\n'
# ...

# %%
ar.return_tool()
# Out:
# ok
#
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000,WP
# os:-1.000,0.000,0.000>
# ok
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processi'
# MESSAGE: 'ng\n'
# MESSAGE: 'ech'
# MESSAGE: 'o:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:389.20 Y:66.60 Z:0.00 E:0.00 Count X:7784 Y:1332 Z:0\nok\n'

# %%
ar.openTool()

# %%
ar.closeTool()

# %%
ar

# %%
ar.writeAndWait("G0 Z300 F1000")
# Out:
# MESSAGE: 'ok\n'

# %%
ar.writeAndWait("G28 Z")
# Out:
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo'
# MESSAGE: ':busy: processing\n'
# MESSAGE: 'X:240.76 Y:66.70 Z:0.00 E:0.00 Count X:4815 Y:1334 Z:0\nok\n'
