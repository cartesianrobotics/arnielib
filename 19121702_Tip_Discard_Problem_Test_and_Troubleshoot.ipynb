# %%
import arnielib as a

# %% [markdown]
# # TODO
#
# 1. Fix 1000 uL tool so servo does not miss pipette ejection tool
# 2. Figure out why 200 uL tool does not move servo at all

# %%
a.serial_ports()
# Out:
# ['COM6', 'COM18']

# %%
ar = a.connect()
# Out:
# ERROR: Couldn't close the port.
# Msg: Arnie's stationary touch probe
# Rev. 1.0, 11/20/2019
#
# ERROR: Couldn't close the port.
# Msg: start
# echo:Marlin 1.1.8
#
# echo: Last Updated: 2017-12-25 12:00 | Author: (none, default config)
# echo:Compiled: Dec 17 2019
# echo: Free Memory: 5437  PlannerBufferBytes: 1232
# echo:Hardcoded Default Settings Loaded
# echo:  G21    ; Units in mm
#
# echo:Filament settings: Disabled
# echo:  M200 D3.00
# echo:  M200 D0
# echo:Steps per unit:
# echo:  M92 X80.00 Y80.00 Z80.00 E500.00
# echo:Maximum feedrates (units/s):
# echo:  M203 X10000.00 Y10000.00 Z10000.00 E25.00
# echo:Maximum Acceleration (units/s2):
# echo:  M201 X10000 Y10000 Z10000 E10000
# echo:Acceleration (units/s2): P<print_accel> R<retract_accel> T<travel_accel>
# echo:  M204 P500.00 R10000.00 T500.00
# echo:Advanced: S<min_feedrate> T<min_travel_feedrate> B<min_segment_time_us> X<max_xy_jerk> Z<max_z_jerk> E<max_e_jerk>
# echo:  M205 S0.00 T0.00 B20000 X10.00 Y10.00 Z10.00 E5.00
# echo:Home offset:
# echo:  M206 X0.00 Y0.00 Z0.00
# echo:PID settings:
# echo:  M301 P22.20 I1.08 D114.00
# echo:Z-Probe Offset (mm):
# echo:  M851 Z0.00
#
# Connected. Homing.
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:'
# MESSAGE: '0.00 Count X:0 Y:0 Z:800\nok\n'
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:0.00 Count X:0 Y:0 Z:800\nok\n'
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:0.00 Count X:0 Y:0 Z:800\nok\n'
# Done.

# %% [markdown]
# # Trying 1000 uL pipettor
#
# I know that this pipettor fails to discard tips

# %%
a.get_tool(ar, type="pipettor", subtype="single", volume=1000)
# Out:
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:0.00 Count X:0 Y:0'
# MESSAGE: ' Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: proc'
# MESSAGE: 'essing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processi'
# MESSAGE: 'ng\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: p'
# MESSAGE: 'rocessing\n'
# MESSAGE: 'X:783.85 Y:132.10 Z:10.00 E:0.00 Count X:62708 Y:10568 Z:800\nok\n'
# ERROR: Couldn't close the port.
# Msg:
# Grbl Eh Servo 0.9j ['$' for he
# [Caution: Unlocked]
# ok
# ok
# error: Not idle
#
# <Run,MPos:-0.800,0.000,0.000,WPos:-0.800,0.000,0.000>
# ok
#
# <Run,MPos:-2.240,0.000,0.000,WPos:-2.240,0.000,0.000>
# ok
#
# <Run,MPos:-2.960,0.000,0.000,WPos:-2.960,0.000,0.000>
# ok
#
# <Run,MPos:-3.900,0.000,0.000,WPos:-3.900,0.000,0.000>
# ok
#
# <Run,MPos:-4.620,0.000,0.000,WPos:-4.620,0.000,0.000>
# ok
#
# <Idle,MPos:-5.000,0.000,0.000,WPos:-5.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000,WP
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok

# %%
# Calibrating against stalagmite
a.calibrate_pipettor_tip(robot=ar, x_n=0, y_n=0)
# Out:
# MESSAGE: 'X:783.85 Y:132.10 Z:10.00 E:0.00 Count X:62708 Y:10568 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4131.50 E:0.00 Count X:15188 Y:10392 Z:330520\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4176.50 E:0.00 Count X:15188 Y:10392 Z:334120\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4221.50 E:0.00 Count X:15188 Y:10392 Z:337720\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4266.50 E:0.00 Count X:15188 Y:10392 Z:341320\nok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4266.50 E:0.00 Count X:15188 Y:10392 Z:341320\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4261.50 E:0.00 Count X:15188 Y:10392 Z:340920\nok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4261.50 E:0.00 Count X:15188 Y:10392 Z:340920\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4261.60 E:0.00 Count X:15188 Y:10392 Z:340928\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4261.70 E:0.00 Count X:15188 Y:10392 Z:340936\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4261.80 E:0.00 Count X:15188 Y:10392 Z:340944\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4261.90 E:0.00 Count X:15188 Y:10392 Z:340952\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.00 E:0.00 Count X:15188 Y:10392 Z:340960\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.10 E:0.00 Count X:15188 Y:10392 Z:340968\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.20 E:0.00 Count X:15188 Y:10392 Z:340976\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.30 E:0.00 Count X:15188 Y:10392 Z:340984\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.40 E:0.00 Count X:15188 Y:10392 Z:340992\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.50 E:0.00 Count X:15188 Y:10392 Z:341000\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.60 E:0.00 Count X:15188 Y:10392 Z:341008\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.70 E:0.00 Count X:15188 Y:10392 Z:341016\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.80 E:0.00 Count X:15188 Y:10392 Z:341024\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4262.90 E:0.00 Count X:15188 Y:10392 Z:341032\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.00 E:0.00 Count X:15188 Y:10392 Z:341040\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.10 E:0.00 Count X:15188 Y:10392 Z:341048\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.20 E:0.00 Count X:15188 Y:10392 Z:341056\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.30 E:0.00 Count X:15188 Y:10392 Z:341064\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.40 E:0.00 Count X:15188 Y:10392 Z:341072\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.50 E:0.00 Count X:15188 Y:10392 Z:341080\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.60 E:0.00 Count X:15188 Y:10392 Z:341088\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.70 E:0.00 Count X:15188 Y:10392 Z:341096\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.80 E:0.00 Count X:15188 Y:10392 Z:341104\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4263.90 E:0.00 Count X:15188 Y:10392 Z:341112\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4264.00 E:0.00 Count X:15188 Y:10392 Z:341120\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4264.10 E:0.00 Count X:15188 Y:10392 Z:341128\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4264.20 E:0.00 Count X:15188 Y:10392 Z:341136\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4264.30 E:0.00 Count X:15188 Y:10392 Z:341144\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4264.40 E:0.00 Count X:15188 Y:10392 Z:341152\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4264.50 E:0.00 Count X:15188 Y:10392 Z:341160\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4264.60 E:0.00 Count X:15188 Y:10392 Z:341168\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4264
Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:111.90 Z:4315.00 E:0.00 Count X:15188 Y:8952 Z:345200\nok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:111.90 Z:4315.00 E:0.00 Count X:15188 Y:8952 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.00 Z:4315.00 E:0.00 Count X:15188 Y:8960 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.10 Z:4315.00 E:0.00 Count X:15188 Y:8968 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.20 Z:4315.00 E:0.00 Count X:15188 Y:8976 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.30 Z:4315.00 E:0.00 Count X:15188 Y:8984 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.40 Z:4315.00 E:0.00 Count X:15188 Y:8992 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.50 Z:4315.00 E:0.00 Count X:15188 Y:9000 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.60 Z:4315.00 E:0.00 Count X:15188 Y:9008 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.70 Z:4315.00 E:0.00 Count X:15188 Y:9016 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.80 Z:4315.00 E:0.00 Count X:15188 Y:9024 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.90 Z:4315.00 E:0.00 Count X:15188 Y:9032 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:113.00 Z:4315.00 E:0.00 Count X:15188 Y:9040 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:113.10 Z:4315.00 E:0.00 Count X:15188 Y:9048 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:113.20 Z:4315.00 E:0.00 Count X:15188 Y:9056 Z:345200\nok\n'
# MESSAGE: 'X:189.85 Y:113.20 Z:4315.00 E:0.00 Count X:15188 Y:9056 Z:345200\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
# Taking a tip
ar.move(z=3000)
a.pickup_tip(robot=ar, x_n=0, y_n=2, well_x_n=0, well_y_n=3)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'X:81.33 Y:562.45 Z:4574.20 E:0.00 Count X:6506 Y:44996 Z:365936\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
a.return_tip(robot=ar, x_n=0, y_n=2, well_x_n=0, well_y_n=3)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-7-c5ad4df34597> in <module>()
# ----> 1 a.return_tip(robot=ar, x_n=0, y_n=2, well_x_n=0, well_y_n=3)
#
# C:\Users\sergiispam\Dropbox\workspace\arnielib\arnielib.py in return_tip(robot, x_n, y_n, well_x_n, well_y_n)
#    1464         robot.move(x=dest_x, y=dest_y)
#    1465         robot.move(z=appr_z)
# -> 1466         robot.current_tool_device.drop_tip()
#    1467
#    1468         robot.move_delta(dz = -100 * u_in_mm[2])
#
# C:\Users\sergiispam\Dropbox\workspace\arnielib\arnielib.py in drop_tip(self, plunger_lower, plunger_raise)
#     339                                 Do not set to 0, as this may cause problem when parking the servo.
#     340 		"""
# --> 341                 self.home()     # Home the pipettor
#     342                 self.write_wait("M3 S90")       # Making sure servo lever is in the upper position
#     343                 self.readAll()
#
# C:\Users\sergiispam\Dropbox\workspace\arnielib\arnielib.py in home(self)
#     320
#     321         def home(self):
# --> 322                 set_pipettor_speed(self, 400)
#     323                 self.write_wait("$H")
#     324                 self.readAll()
#
# C:\Users\sergiispam\Dropbox\workspace\arnielib\arnielib.py in set_pipettor_speed(pipettor, speed)
#    1570
#    1571 def set_pipettor_speed(pipettor, speed):
# -> 1572         pipettor.write_wait("$110=" + str(speed) + "\n")
#    1573
#    1574 # All pipetting functions assume that the pipettor tip hovers 2mm above the well, and return to that position at the end.
#
# C:\Users\sergiispam\Dropbox\workspace\arnielib\arnielib.py in write_wait(self, expression, confirm_message, eol)
#     306                 Function will return an output message
#     307 		"""
# --> 308                 self.write(expression, eol)
#     309
#     310                 full_message = ""
#
# C:\Users\sergiispam\Dropbox\workspace\arnielib\arnielib.py in write(self, expression, eol)
#     247                 message_log(self.port_name, expression, "write")
#     248                 # Writing to robot
# --> 249                 self.port.write(expr_enc)
#     250
#     251
#
# C:\Users\sergiispam\Anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     313             if self._write_timeout != 0:  # if blocking (None) or w/ write timeout (>0)
#     314                 if not success and win32.GetLastError() not in (win32.ERROR_SUCCESS, win32.ERROR_IO_PENDING):
# --> 315                     raise SerialException("WriteFile failed ({!r})".format(ctypes.WinError()))
#     316
#     317                 # Wait for the write to complete.
#
# SerialException: WriteFile failed (PermissionError(13, 'Access is denied.', None, 5))

# %%
ar.return_tool()

# %% [markdown]
# # Testing 200 uL pipette
#
# This one does not react to M3/M5 at all

# %%
a.get_tool(ar, type="pipettor", subtype="single", volume=200)
a.calibrate_pipettor_tip(robot=ar, x_n=0, y_n=0)
ar.move(z=2000)
a.pickup_tip(robot=ar, x_n=2, y_n=2, well_x_n=0, well_y_n=3)

# %%
#ar.current_tool_device.write("M3 S90")

# %%
#ar.current_tool_device.write("M5")

# %%
ar.current_tool_device.write_wait("M5")

# %%
#ar.current_tool_device.write_wait("M3 S90")

# %%
a.return_tip(robot=ar, x_n=2, y_n=2, well_x_n=0, well_y_n=3)

# %%
ar.return_tool()

# %%
# Trying again
a.get_tool(ar, type="pipettor", subtype="single", volume=200)

# %%
a.return_tip(robot=ar, x_n=2, y_n=2, well_x_n=0, well_y_n=3)

# %% [markdown]
# # Testing 20 uL pipette
#
# Returned tip properly

# %%
a.get_tool(ar, type="pipettor", subtype="single", volume=20)

# %%
ar.move(z=2000)
a.calibrate_pipettor_tip(robot=ar, x_n=0, y_n=0)
ar.move(z=2000)
a.pickup_tip(robot=ar, x_n=4, y_n=2, well_x_n=0, well_y_n=3)

# %%
a.return_tip(robot=ar, x_n=4, y_n=2, well_x_n=0, well_y_n=3)
# returned properly

# %%
ar.return_tool()

# %%
ar.openTool()

# %%
ar.home()
# Out:
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: pro'
# MESSAGE: 'cessing\n'
# MESSAGE: 'echo:busy: pr'
# MESSAGE: 'ocessing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy:'
# MESSAGE: ' processing\n'
# MESSAGE: 'echo:bus'
# MESSAGE: 'y: processing\n'
# MESSAGE: 'echo:b'
# MESSAGE: 'usy: processing\n'
# MESSAGE: 'echo'
# MESSAGE: ':busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:81.18 Y:'
# MESSAGE: '562.85 Z:10.00 E:0.00 Count X:6494 Y:45028 Z:800\nok\n'
# MESSAGE: 'X:0.00 Y:562.85 Z:10.00 E:0.00 Count X:0 Y:45028 Z:800\nok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:0.00 Count X:0 Y:0 Z:800\nok\n'
