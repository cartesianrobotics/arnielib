# %%
import arnielib as a

# %% [markdown]
# # TODO
#
# 1. Fix 1000 uL tool so servo does not miss pipette ejection tool
# 2. Figure out why 200 uL tool does not move servo at all

# %%
a.serial_ports()
# Out:
# ['COM6']

# %%
ar = a.connect()
# Out:
# ERROR: Couldn't close the port.
# Msg: Arnie's stationary touch probe
# Rev. 1.0, 11/20/2019
#
# ERROR: Couldn't close the port.
# Msg: start
# echo:Marlin 1.1.8
#
# echo: Last Updated: 2017-12-25 12:00 | Author: (none, default config)
# echo:Compiled: Dec 17 2019
# echo: Free Memory: 5437  PlannerBufferBytes: 1232
# echo:Hardcoded Default Settings Loaded
# echo:  G21    ; Units in mm
#
# echo:Filament settings: Disabled
# echo:  M200 D3.00
# echo:  M200 D0
# echo:Steps per unit:
# echo:  M92 X80.00 Y80.00 Z80.00 E500.00
# echo:Maximum feedrates (units/s):
# echo:  M203 X10000.00 Y10000.00 Z10000.00 E25.00
# echo:Maximum Acceleration (units/s2):
# echo:  M201 X10000 Y10000 Z10000 E10000
# echo:Acceleration (units/s2): P<print_accel> R<retract_accel> T<travel
# Connected. Homing.
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:0.00 Count X:0 '
# MESSAGE: 'Y:0 Z:800\nok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00'
# MESSAGE: ' E:0.00 Count X:0 Y:0 Z:800\nok\n'
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:0.00 Cou'
# MESSAGE: 'nt X:0 Y:0 Z:800\nok\n'
# Done.

# %% [markdown]
# # Trying 1000 uL pipettor
#
# I know that this pipettor fails to discard tips

# %%
a.get_tool(ar, type="pipettor", subtype="single", volume=1000)
# Out:
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:0.'
# MESSAGE: '00 Count X:0 Y:0 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:b'
# MESSAGE: 'usy: processing\n'
# MESSAGE: 'ec'
# MESSAGE: 'ho:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: p'
# MESSAGE: 'rocessing\n'
# MESSAGE: 'echo:bu'
# MESSAGE: 'sy: processing\n'
# MESSAGE: 'ech'
# MESSAGE: 'o:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: proce'
# MESSAGE: 'ssing\n'
# MESSAGE: 'echo:busy: '
# MESSAGE: 'processing\n'
# MESSAGE: 'X:784.00 Y:133.00 Z:10.00 E:0.00 Count X:62720 Y:10640 Z:800\nok\n'
# ERROR: Couldn't close the port.
# Msg:
# Grbl Eh Servo 0.9j ['$' for he
# [Caution: Unlocked]
# ok
# ok
# error: Not idle
#
# <Run,MPos:-0.500,0.000,0.000,WPos:-0.500,0.000,0.000>
# ok
#
# <Run,MPos:-1.160,0.000,0.000,WPos:-1.160,0.000,0.000>
# ok
#
# <Run,MPos:-2.020,0.000,0.000,WPos:-2.020,0.000,0.000>
# ok
#
# <Run,MPos:-2.900,0.000,0.000,WPos:-2.900,0.000,0.000>
# ok
#
# <Run,MPos:-3.720,0.000,0.000,WPos:-3.720,0.000,0.000>
# ok
#
# <Run,MPos:-4.600,0.000,0.000,WPos:-4.600,0.000,0.000>
# ok
#
# <Idle,MPos:-5.000,0.000,0.000,WPos:-5.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:100.56 Z:4315.72 E:0.00 Count X:15188 Y:8045 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:110.56 Z:4315.72 E:0.00 Count X:15188 Y:8845 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:120.56 Z:4315.72 E:0.00 Count X:15188 Y:9645 Z:345258\nok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:120.56 Z:4315.72 E:0.00 Count X:15188 Y:9645 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:119.56 Z:4315.72 E:0.00 Count X:15188 Y:9565 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:118.56 Z:4315.72 E:0.00 Count X:15188 Y:9485 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:117.56 Z:4315.72 E:0.00 Count X:15188 Y:9405 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:116.56 Z:4315.72 E:0.00 Count X:15188 Y:9325 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:115.56 Z:4315.72 E:0.00 Count X:15188 Y:9245 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:114.56 Z:4315.72 E:0.00 Count X:15188 Y:9165 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:113.56 Z:4315.72 E:0.00 Count X:15188 Y:9085 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:112.56 Z:4315.72 E:0.00 Count X:15188 Y:9005 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:111.56 Z:4315.72 E:0.00 Count X:15188 Y:8925 Z:345258\nok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:111.56 Z:4315.72 E:0.00 Count X:15188 Y:8925 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:111.66 Z:4315.72 E:0.00 Count X:15188 Y:8933 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:111.76 Z:4315.72 E:0.00 Count X:15188 Y:8941 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:111.86 Z:4315.72 E:0.00 Count X:15188 Y:8949 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:111.96 Z:4315.72 E:0.00 Count X:15188 Y:8957 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.06 Z:4315.72 E:0.00 Count X:15188 Y:8965 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.16 Z:4315.72 E:0.00 Count X:15188 Y:8973 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.26 Z:4315.72 E:0.00 Count X:15188 Y:8981 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.36 Z:4315.72 E:0.00 Count X:15188 Y:8989 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.46 Z:4315.72 E:0.00 Count X:15188 Y:8997 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.56 Z:4315.72 E:0.00 Count X:15188 Y:9005 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.66 Z:4315.72 E:0.00 Count X:15188 Y:9013 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.76 Z:4315.72 E:0.00 Count X:15188 Y:9021 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.86 Z:4315.72 E:0.00 Count X:15188 Y:9029 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:112.96 Z:4315.72 E:0.00 Count X:15188 Y:9037 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:113.06 Z:4315.72 E:0.00 Count X:15188 Y:9045 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:113.16 Z:4315.72 E:0.00 Count X:15188 Y:9053 Z:345258\nok\n'
# MESSAGE: 'X:189.85 Y:113.16 Z:4315.72 E:0.00 Count X:15188 Y:9053 Z:345258\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
# Taking a tip
ar.move(z=3000)
a.pickup_tip(robot=ar, x_n=0, y_n=2, well_x_n=0, well_y_n=3)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'X:82.12 Y:562.08 Z:4561.80 E:0.00 Count X:6570 Y:44966 Z:364944\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
a.return_tip(robot=ar, x_n=0, y_n=2, well_x_n=0, well_y_n=3)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ok
#
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000,WP
# os:-1.000,0.000,0.000>
# ok
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# ok
#
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Run,MPos:-1.500,0.000,0.000,WPos:-1.500,0.000,0.000>
# ok
#
# <Run,MPos:-2.500,0.000,0.000,WPos:-2.500,0.000,0.000>
# ok
#
# <Run,MPos:-3.160,0.000,0.000,WPos:-3.160,0.000,0.000>
# ok
#
# <Run,MPos:-4.100,0.000,0.000,WPos:-4.100,0.000,0.000>
# ok
#
# <Run,MPos:-5.060,0.000,0.000,WPos:-5.060,0.000,0.000>
# ok
#
# <Run,MPos:-5.900,0.000,0.000,WPos:-5.900,0.000,0.000>
# ok
#
# <Run,MPos:-6.780,0.000,0.000,WPos:-6.780,0.000,0.000>
# ok
#
# <Run,MPos:-7.720,0.000,0.000,WPos:-7.720,0.000,0.000>
# ok
#
# <Run,MPos:-8.700,0.000,0.000,WPos:-8.700,0.000,0.000>
# ok
#
# <Run,MPos:-9.640,0.000,0.000,WPos:-9.640,0.000,0.000>
# ok
#
# <Run,MPos:-10.300,0.000,0.000,WPos:-10.300,0.000,0.000>
# ok
#
# <Run,MPos:-11.100,0.000,0.000,WPos:-11.100,0.000,0.000>
# ok
#
# <Run,MPos:-11.780,0.000,0.000,WPos:-11.780,0.000,0.000>
# ok
#
# <Run,MPos:-12.560,0.000,0.000,WPos:-12.560,0.000,0.000>
# ok
#
# <Run,MPos:-13.520,0.000,0.000,WPos:-13.520,0.000,0.000>
# ok
#
# <Run,MPos:-14.460,0.000,0.000,WPos:-14.460,0.000,0.000>
# ok
#
# <Run,MPos:-15.100,0.000,0.000,WPos:-15.100,0.000,0.000>
# ok
#
# <Run,MPos:-15.880,0.000,0.000,WPos:-15.880,0.000,0.000>
# ok
#
# <Run,MPos:-16.560,0.000,0.000,WPos:-16.560,0.000,0.000>
# ok
#
# <Run,MPos:-17.380,0.000,0.000,WPos:-17.380,0.000,0.000>
# ok
#
# <Run,MPos:-18.340,0.000,0.000,WPos:-18.340,0.000,0.000>
# ok
#
# <Run,MPos:-19.240,0.000,0.000,WPos:-19.240,0.000,0.000>
# ok
#
# <Run,MPos:-20.140,0.000,0.000,WPos:-20.140,0.000,0.000>
# ok
#
# <Run,MPos:-20.960,0.000,0.000,WPos:-20.960,0.000,0.000>
# ok
#
# <Run,MPos:-22.000,0.000,0.000,WPos:-22.000,0.000,0.000>
# ok
#
# <Run,MPos:-22.860,0.000,0.000,WPos:-22.860,0.000,0.000>
# ok
#
# <Run,MPos:-23.820,0.000,0.000,WPos:-23.820,0.000,0.000>
# ok
#
# <Run,MPos:-24.620,0.000,0.000,WPos:-24.620,0.000,0.000>
# ok
#
# <Run,MPos:-25.540,0.000,0.000,WPos:-25.540,0.000,0.000>
# ok
#
# <Run,MPos:-26.520,0.000,0.000,WPos:-26.520,0.000,0.000>
# ok
#
# <Run,MPos:-27.220,0.000,0.000,WPos:-27.220,0.000,0.000>
# ok
#
# <Run,MPos:-27.980,0.000,0.000,WPos:-27.980,0.000,0.000>
# ok
#
# <Run,MPos:-28.720,0.000,0.000,WPos:-28.720,0.000,0.000>
# ok
#
# <Run,MPos:-29.500,0.000,0.000,WPos:-29.500,0.000,0.000>
# ok
#
# <Run,MPos:-30.260,0.000,0.000,WPos:-30.260,0.000,0.000>
# ok
#
# <Run,MPos:-31.000,0.000,0.000,WPos:-31.000,0.000,0.000>
# ok
#
# <Run,MPos:-31.680,0.000,0.000,WPos:-31.680,0.000,0.000>
# ok
#
# <Run,MPos:-32.440,0.000,0.000,WPos:-32.440,0.000,0.000>
# ok
#
# <Run,MPos:-33.120,0.000,0.000,WPos:-33.120,0.000,0.000>
# ok
#
# <Run,MPos:-33.880,0.000,0.000,WPos:-33.880,0.000,0.000>
# ok
#
# <Run,MPos:-34.580,0.000,0.000,WPos:-34.580,0.000,0.000>
# ok
#
# <Run,MPos:-35.360,0.000,0.000,WPos:-35.360,0.000,0.000>
# ok
#
# <Run,MPos:-36.020,0.000,0.000,WPos:-36.020,0.000,0.000>
# ok
#
# <Run,MPos:-36.780,0.000,0.000,WPos:-36.780,0.000,0.000>
# ok
#
# <Run,MPos:-37.460,0.000,0.000,WPos:-37.460,0.000,0.000>
# ok
#
# <Run,MPos:-38.220,0.000,0.000,WPos:-38.220,0.000,0.000>
# ok
#
# <Run,MPos:-38.900,0.000,0.000,WPos:-38.900,0.000,0.000>
# ok
#
# <Run,MPos:-39.700,0.000,0.000,WPos:-39.700,0.000,0.000>
# ok
#
# <Run,MPos:-40.000,0.000,0.000,WPos:-40.000,0.000,0.000>
# ok
#
# <Idle,MPos:-40.000,0.000,0.000,WPos:-40.000,0.000,0.000>
# ok
#
# ok
#
# <Run,MPos:-39.520,0.000,0.000,WPos:-39.520,0.000,0.000>
# ok
#
# <Run,MPos:-38.780,0.000,0.000,WPos:-38.780,0.000,0.000>
# ok
#
# <Run,MPos:-38.120,0.000,0.000,WPos:-38.120,0.000,0.000>
# ok
#
# <Run,MPos:-37.340,0.000,0.000,WPos:-37.340,0.000,0.000>
# ok
#
# <Run,MPos:-36.660,0.000,0.000,WPos:-36.660,0.000,0.000>
# ok
#
# <Run,MPos:-35.900,0.000,0.000,WPos:-35.900,0.000,0.000>
# ok
#
# <Run,MPos:-35.220,0.000,0.000,WPos:-35.220,0.000,0.000>
# ok
#
# <Run,MPos:-34.440,0.000,0.000,WPos:-34.440,0.000,0.000>
# ok
#
# <Run,MPos:-33.760,0.000,0.000,WPos:-33.760,0.000,0.000>
# ok
#
# <Run,MPos:-33.000,0.000,0.000,WPos:-33.000,0.000,0.000>
# ok
#
# <Run,MPos:-32.240,0.000,0.000,WPos:-32.240,0.000,0.000>
# ok
#
# <Run,MPos:-31.400,0.000,0.000,WPos:-31.400,0.000,0.000>
# ok
#
# <Run,MPos:-30.720,0.000,0.000,WPos:-30.720,0.000,0.000>
# ok
#
# <Run,MPos:-30.000,0.000,0.000,WPos:-30.000,0.000,0.000>
# ok
#
# <Run,MPos:-29.280,0.000,0.000,WPos:-29.280,0.000,0.000>
# ok
#
# <Run,MPos:-28.540,0.000,0.000,WPos:-28.540,0.000,0.000>
# ok
#
# <Run,MPos:-27.780,0.000,0.000,WPos:-27.780,0.000,0.000>
# ok
#
# <Run,MPos:-26.940,0.000,0.000,WPos:-26.940,0.000,0.000>
# ok
#
# <Run,MPos:-26.280,0.000,0.000,WPos:-26.280,0.000,0.000>
# ok
#
# <Run,MPos:-25.560,0.000,0.000,WPos:-25.560,0.000,0.000>
# ok
#
# <Run,MPos:-24.840,0.000,0.000,WPos:-24.840,0.000,0.000>
# ok
#
# <Run,MPos:-24.100,0.000,0.000,WPos:-24.100,0.000,0.000>
# ok
#
# <Run,MPos:-23.420,0.000,0.000,WPos:-23.420,0.000,0.000>
# ok
#
# <Run,MPos:-22.660,0.000,0.000,WPos:-22.660,0.000,0.000>
# ok
#
# <Run,MPos:-21.940,0.000,0.000,WPos:-21.940,0.000,0.000>
# ok
#
# <Run,MPos:-21.220,0.000,0.000,WPos:-21.220,0.000,0.000>
# ok
#
# <Run,MPos:-20.520,0.000,0.000,WPos:-20.520,0.000,0.000>
# ok
#
# <Run,MPos:-19.760,0.000,0.000,WPos:-19.760,0.000,0.000>
# ok
#
# <Run,MPos:-19.080,0.000,0.000,WPos:-19.080,0.000,0.000>
# ok
#
# <Run,MPos:-18.320,0.000,0.000,WPos:-18.320,0.000,0.000>
# ok
#
# <Run,MPos:-17.640,0.000,0.000,WPos:-17.640,0.000,0.000>
# ok
#
# <Run,MPos:-16.880,0.000,0.000,WPos:-16.880,0.000,0.000>
# ok
#
# <Run,MPos:-16.220,0.000,0.000,WPos:-16.220,0.000,0.000>
# ok
#
# <Run,MPos:-15.440,0.000,0.000,WPos:-15.440,0.000,0.000>
# ok
#
# <Run,MPos:-14.760,0.000,0.000,WPos:-14.760,0.000,0.000>
# ok
#
# <Run,MPos:-13.980,0.000,0.000,WPos:-13.980,0.000,0.000>
# ok
#
# <Run,MPos:-13.300,0.000,0.000,WPos:-13.300,0.000,0.000>
# ok
#
# <Run,MPos:-12.540,0.000,0.000,WPos:-12.540,0.000,0.000>
# ok
#
# <Run,MPos:-11.860,0.000,0.000,WPos:-11.860,0.000,0.000>
# ok
#
# <Run,MPos:-11.100,0.000,0.000,WPos:-11.100,0.000,0.000>
# ok
#
# <Run,MPos:-10.420,0.000,0.000,WPos:-10.420,0.000,0.000>
# ok
#
# <Run,MPos:-9.680,0.000,0.000,WPos:-9.680,0.000,0.000>
# ok
#
# <Run,MPos:-9.000,0.000,0.000,WPos:-9.000,0.000,0.000>
# ok
#
# <Run,MPos:-8.260,0.000,0.000,WPos:-8.260,0.000,0.000>
# ok
#
# <Run,MPos:-7.560,0.000,0.000,WPos:-7.560,0.000,0.000>
# ok
#
# <Run,MPos:-6.780,0.000,0.000,WPos:-6.780,0.000,0.000>
# ok
#
# <Run,MPos:-6.100,0.000,0.000,WPos:-6.100,0.000,0.000>
# ok
#
# <Run,MPos:-5.400,0.000,0.000,WPos:-5.400,0.000,0.000>
# ok
#
# <Run,MPos:-4.660,0.000,0.000,WPos:-4.660,0.000,0.000>
# ok
#
# <Run,MPos:-3.880,0.000,0.000,WPos:-3.880,0.000,0.000>
# ok
#
# <Run,MPos:-3.200,0.000,0.000,WPos:-3.200,0.000,0.000>
# ok
#
# <Run,MPos:-2.460,0.000,0.000,WPos:-2.460,0.000,0.000>
# ok
#
# <Run,MPos:-2.000,0.000,0.000,WPos:-2.000,0.000,0.000>
# ok
#
# <Idle,MPos:-2.000,0.000,0.000,WPos:-2.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:-2.000,0.000,0.000,WPos:-2.000,0.000,0.000>
# ok
#
# MESSAGE: 'X:82.12 Y:562.08 Z:4430.83 E:0.00 Count X:6570 Y:44966 Z:354466\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
ar.return_tool()
# Out:
# ok
#
# <Idle,MPos:-2.000,0.000,0.000,WPos:-2.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# <Idle,MPos:-1.000,0.000,0.000,WPos:-1.000,0.000,0.000>
# ok
#
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing'
# MESSAGE: '\n'
# MESSAGE: 'echo'
# MESSAGE: ':busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:8'
# MESSAGE: '2.12 Y:562.08 Z:10.00 E:0.00 Count X:6570 Y:44966 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: pr'
# MESSAGE: 'ocessing\n'
# MESSAGE: 'echo:busy'
# MESSAGE: ': processing\n'
# MESSAGE: 'ech'
# MESSAGE: 'o:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:784.00 Y:133.00 Z:10.00 E:0.00 Count X:62720 Y:10640 Z:800\nok\n'

# %% [markdown]
# # Testing 200 uL pipette
#
# This one does not react to M3/M5 at all

# %%
a.get_tool(ar, type="pipettor", subtype="single", volume=200)
a.calibrate_pipettor_tip(robot=ar, x_n=0, y_n=0)
ar.move(z=2000)
a.pickup_tip(robot=ar, x_n=2, y_n=2, well_x_n=0, well_y_n=3)
# Out:
# MESSAGE: 'X:0.00 Y:0.00 Z:10.00 E:0.00 Count X:0 Y:0 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: pro'
# MESSAGE: 'cessing\n'
# MESSAGE: 'echo:bus'
# MESSAGE: 'y: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processi'
# MESSAGE: 'ng\n'
# MESSAGE: 'echo:busy: proc'
# MESSAGE: 'essing\n'
# MESSAGE: 'X:1083.80 Y:132.45 Z:10.00 E:0.00 '
# MESSAGE: 'Count X:86704 Y:10596 Z:800\nok\n'
# ERROR: Couldn't close the port.
# Msg:
# Grbl Eh Servo 0.9j ['$' for help]
# ['$H'|'$X' to unlock]
#
# [Caution: Unlocked]
# ok
# ok
# error: Not idle
#
# <Run,MPos:-0.620,0.000,0.000>
# ok
#
# <Run,MPos:-1.400,0.000,0.000>
# ok
#
# <Run,MPos:-2.100,0.000,0.000>
# ok
#
# <Run,MPos:-3.420,0.000,0.000>
# ok
#
# <Run,MPos:-4.300,0.000,0.000>
# ok
#
# <Idle,MPos:-5.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# MESSAGE: 'X'
# MESSAGE: ':1083.80 Y:132.45 Z:10.00 E:0.00 Count X:86704 Y:10596 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4117.25 E:0.00 Count X:15188 Y:10392 Z:329380\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:
nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:90.56 Z:4597.02 E:0.00 Count X:15188 Y:7245 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:100.56 Z:4597.02 E:0.00 Count X:15188 Y:8045 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:110.56 Z:4597.02 E:0.00 Count X:15188 Y:8845 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:120.56 Z:4597.02 E:0.00 Count X:15188 Y:9645 Z:367762\nok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:120.56 Z:4597.02 E:0.00 Count X:15188 Y:9645 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:119.56 Z:4597.02 E:0.00 Count X:15188 Y:9565 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:118.56 Z:4597.02 E:0.00 Count X:15188 Y:9485 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:117.56 Z:4597.02 E:0.00 Count X:15188 Y:9405 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:116.56 Z:4597.02 E:0.00 Count X:15188 Y:9325 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:115.56 Z:4597.02 E:0.00 Count X:15188 Y:9245 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:114.56 Z:4597.02 E:0.00 Count X:15188 Y:9165 Z:367762\nok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:114.56 Z:4597.02 E:0.00 Count X:15188 Y:9165 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:114.66 Z:4597.02 E:0.00 Count X:15188 Y:9173 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:114.76 Z:4597.02 E:0.00 Count X:15188 Y:9181 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:114.86 Z:4597.02 E:0.00 Count X:15188 Y:9189 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:114.96 Z:4597.02 E:0.00 Count X:15188 Y:9197 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.06 Z:4597.02 E:0.00 Count X:15188 Y:9205 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.16 Z:4597.02 E:0.00 Count X:15188 Y:9213 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.26 Z:4597.02 E:0.00 Count X:15188 Y:9221 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.36 Z:4597.02 E:0.00 Count X:15188 Y:9229 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.46 Z:4597.02 E:0.00 Count X:15188 Y:9237 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.56 Z:4597.02 E:0.00 Count X:15188 Y:9245 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.66 Z:4597.02 E:0.00 Count X:15188 Y:9253 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.76 Z:4597.02 E:0.00 Count X:15188 Y:9261 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.86 Z:4597.02 E:0.00 Count X:15188 Y:9269 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:115.96 Z:4597.02 E:0.00 Count X:15188 Y:9277 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:116.06 Z:4597.02 E:0.00 Count X:15188 Y:9285 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:116.16 Z:4597.02 E:0.00 Count X:15188 Y:9293 Z:367762\nok\n'
# MESSAGE: 'X:189.85 Y:116.16 Z:4597.02 E:0.00 Count X:15188 Y:9293 Z:367762\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'X:685.85 Y:566.38 Z:5153.04 E:0.00 Count X:54868 Y:45310 Z:412243\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
#ar.current_tool_device.write("M3 S90")

# %%
#ar.current_tool_device.write("M5")

# %%
ar.current_tool_device.write_wait("M5")
# Out:
# ok
#
# <Idle,MPos:0.000,0.000,0.000>
# ok

# %%
#ar.current_tool_device.write_wait("M3 S90")
# Out:
# ok
#
# <Idle,MPos:0.000,0.000,0.000>
# ok

# %%
a.return_tip(robot=ar, x_n=2, y_n=2, well_x_n=0, well_y_n=3)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000>
#
# ok
# <Idle,MPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Run,MPos:-1.500,0.000,0.000>
# ok
#
# <Run,MPos:-2.260,0.000,0.000>
# ok
#
# <Run,MPos:-2.980,0.000,0.000>
# ok
#
# <Run,MPos:-3.700,0.000,0.000>
# ok
#
# <Run,MPos:-4.440,0.000,0.000>
# ok
#
# <Run,MPos:-5.140,0.000,0.000>
# ok
#
# <Run,MPos:-5.880,0.000,0.000>
# ok
#
# <Run,MPos:-6.660,0.000,0.000>
# ok
#
# <Run,MPos:-7.600,0.000,0.000>
# ok
#
# <Run,MPos:-8.560,0.000,0.000>
# ok
#
# <Run,MPos:-9.560,0.000,0.000>
# ok
#
# <Run,MPos:-10.220,0.000,0.000>
# ok
#
# <Run,MPos:-10.900,0.000,0.000>
# ok
#
# <Run,MPos:-11.820,0.000,0.000>
# ok
#
# <Run,MPos:-12.440,0.000,0.000>
# ok
#
# <Run,MPos:-13.220,0.000,0.000>
# ok
#
# <Run,MPos:-14.020,0.000,0.000>
# ok
#
# <Run,MPos:-14.860,0.000,0.000>
# ok
#
# <Run,MPos:-15.460,0.000,0.000>
# ok
#
# <Run,MPos:-16.260,0.000,0.000>
# ok
#
# <Run,MPos:-16.920,0.000,0.000>
# ok
#
# <Run,MPos:-17.900,0.000,0.000>
# ok
#
# <Run,MPos:-18.920,0.000,0.000>
# ok
#
# <Run,MPos:-19.680,0.000,0.000>
# ok
#
# <Run,MPos:-20.340,0.000,0.000>
# ok
#
# <Run,MPos:-21.180,0.000,0.000>
# ok
#
# <Run,MPos:-22.160,0.000,0.000>
# ok
#
# <Run,MPos:-23.180,0.000,0.000>
# ok
#
# <Run,MPos:-24.160,0.000,0.000>
# ok
#
# <Run,MPos:-25.040,0.000,0.000>
# ok
#
# <Run,MPos:-25.900,0.000,0.000>
# ok
#
# <Run,MPos:-26.720,0.000,0.000>
# ok
#
# <Run,MPos:-27.600,0.000,0.000>
# ok
#
# <Run,MPos:-28.460,0.000,0.000>
# ok
#
# <Run,MPos:-29.320,0.000,0.000>
# ok
#
# <Run,MPos:-30.140,0.000,0.000>
# ok
#
# <Run,MPos:-31.040,0.000,0.000>
# ok
#
# <Run,MPos:-31.940,0.000,0.000>
# ok
#
# <Run,MPos:-32.560,0.000,0.000>
# ok
#
# <Run,MPos:-33.340,0.000,0.000>
# ok
#
# <Run,MPos:-34.280,0.000,0.000>
# ok
#
# <Run,MPos:-35.300,0.000,0.000>
# ok
#
# <Run,MPos:-36.160,0.000,0.000>
# ok
#
# <Run,MPos:-37.020,0.000,0.000>
# ok
#
# <Run,MPos:-37.880,0.000,0.000>
# ok
#
# <Run,MPos:-38.780,0.000,0.000>
# ok
#
# <Run,MPos:-39.440,0.000,0.000>
# ok
#
# <Run,MPos:-39.980,0.000,0.000>
# ok
#
# <Idle,MPos:-40.000,0.000,0.000>
# ok
#
# ok
#
# <Run,MPos:-39.560,0.000,0.000>
# ok
#
# <Run,MPos:-38.820,0.000,0.000>
# ok
#
# <Run,MPos:-38.100,0.000,0.000>
# ok
#
# <Run,MPos:-37.340,0.000,0.000>
# ok
#
# <Run,MPos:-36.660,0.000,0.000>
# ok
#
# <Run,MPos:-35.920,0.000,0.000>
# ok
#
# <Run,MPos:-35.220,0.000,0.000>
# ok
#
# <Run,MPos:-34.480,0.000,0.000>
# ok
#
# <Run,MPos:-33.760,0.000,0.000>
# ok
#
# <Run,MPos:-33.000,0.000,0.000>
# ok
#
# <Run,MPos:-32.340,0.000,0.000>
# ok
#
# <Run,MPos:-31.580,0.000,0.000>
# ok
#
# <Run,MPos:-30.900,0.000,0.000>
# ok
#
# <Run,MPos:-30.120,0.000,0.000>
# ok
#
# <Run,MPos:-29.460,0.000,0.000>
# ok
#
# <Run,MPos:-28.700,0.000,0.000>
# ok
#
# <Run,MPos:-28.020,0.000,0.000>
# ok
#
# <Run,MPos:-27.260,0.000,0.000>
# ok
#
# <Run,MPos:-26.580,0.000,0.000>
# ok
#
# <Run,MPos:-25.800,0.000,0.000>
# ok
#
# <Run,MPos:-25.100,0.000,0.000>
# ok
#
# <Run,MPos:-24.340,0.000,0.000>
# ok
#
# <Run,MPos:-23.680,0.000,0.000>
# ok
#
# <Run,MPos:-22.860,0.000,0.000>
# ok
#
# <Run,MPos:-22.240,0.000,0.000>
# ok
#
# <Run,MPos:-21.460,0.000,0.000>
# ok
#
# <Run,MPos:-20.760,0.000,0.000>
# ok
#
# <Run,MPos:-20.020,0.000,0.000>
# ok
#
# <Run,MPos:-19.340,0.000,0.000>
# ok
#
# <Run,MPos:-18.580,0.000,0.000>
# ok
#
# <Run,MPos:-17.900,0.000,0.000>
# ok
#
# <Run,MPos:-17.140,0.000,0.000>
# ok
#
# <Run,MPos:-16.480,0.000,0.000>
# ok
#
# <Run,MPos:-15.720,0.000,0.000>
# ok
#
# <Run,MPos:-15.040,0.000,0.000>
# ok
#
# <Run,MPos:-14.340,0.000,0.000>
# ok
#
# <Run,MPos:-13.600,0.000,0.000>
# ok
#
# <Run,MPos:-12.760,0.000,0.000>
# ok
#
# <Run,MPos:-12.120,0.000,0.000>
# ok
#
# <Run,MPos:-11.420,0.000,0.000>
# ok
#
# <Run,MPos:-10.680,0.000,0.000>
# ok
#
# <Run,MPos:-9.880,0.000,0.000>
# ok
#
# <Run,MPos:-9.240,0.000,0.000>
# ok
#
# <Run,MPos:-8.480,0.000,0.000>
# ok
#
# <Run,MPos:-7.800,0.000,0.000>
# ok
#
# <Run,MPos:-6.960,0.000,0.000>
# ok
#
# <Run,MPos:-6.360,0.000,0.000>
# ok
#
# <Run,MPos:-5.580,0.000,0.000>
# ok
#
# <Run,MPos:-4.920,0.000,0.000>
# ok
#
# <Run,MPos:-4.120,0.000,0.000>
# ok
#
# <Run,MPos:-3.460,0.000,0.000>
# ok
#
# <Run,MPos:-2.620,0.000,0.000>
# ok
#
# <Run,MPos:-2.060,0.000,0.000>
# ok
#
# <Idle,MPos:-2.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:-2.000,0.000,0.000>
# ok
#
# MESSAGE: 'X:685.85 Y:566.38 Z:5047.25 E:0.00 Count X:54868 Y:45310 Z:403780\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
ar.return_tool()
# Out:
# ok
#
# <Idle,MPos:-2.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000>
#
# ok
# <Idle,MPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'ec'
# MESSAGE: 'ho:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: proc'
# MESSAGE: 'essing\n'
# MESSAGE: 'echo:busy: '
# MESSAGE: 'processing\n'
# MESSAGE: 'echo:bu'
# MESSAGE: 'sy: processing\n'
# MESSAGE: 'ech'
# MESSAGE: 'o:busy: processing\n'
# MESSAGE: 'X:685.85 Y:566.38 Z:10.00 E:0.00 Count X:54868 Y:45310 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo'
# MESSAGE: ':busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: pro'
# MESSAGE: 'cessing\n'
# MESSAGE: 'echo:busy'
# MESSAGE: ': processing\n'
# MESSAGE: 'echo'
# MESSAGE: ':busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processi'
# MESSAGE: 'ng\n'
# MESSAGE: 'X:1083.80 Y:132.45 Z:10.00 E:0.'
# MESSAGE: '00 Count X:86704 Y:10596 Z:800\nok\n'

# %%
# Trying again
a.get_tool(ar, type="pipettor", subtype="single", volume=200)
# Out:
# MESSAGE: 'X:1083.80'
# MESSAGE: ' Y:132.45 Z:10.00 E:0.00 Count X:86704 Y:10596 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'e'
# MESSAGE: 'cho:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'ech'
# MESSAGE: 'o:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:1083.80 Y:132.45 Z:10.00 '
# MESSAGE: 'E:0.00 Count X:86704 Y:10596 Z:800\nok\n'
# ERROR: Couldn't close the port.
# Msg:
# Grbl Eh Servo 0.9j ['$' for help]
# ['$H'|'$X' to unlock]
#
# [Caution: Unlocked]
# ok
# ok
# error: Not idle
#
# <Run,MPos:-0.620,0.000,0.000>
# ok
#
# <Run,MPos:-1.460,0.000,0.000>
# ok
#
# <Run,MPos:-2.280,0.000,0.000>
# ok
#
# <Run,MPos:-2.920,0.000,0.000>
# ok
#
# <Run,MPos:-3.620,0.000,0.000>
# ok
#
# <Run,MPos:-4.320,0.000,0.000>
# ok
#
# <Run,MPos:-4.940,0.000,0.000>
# ok
#
# <Idle,MPos:-5.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000>
#
# ok
# <Idle,MPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok

# %%
a.return_tip(robot=ar, x_n=2, y_n=2, well_x_n=0, well_y_n=3)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000>
#
# ok
# <Idle,MPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Run,MPos:-1.460,0.000,0.000>
# ok
#
# <Run,MPos:-2.180,0.000,0.000>
# ok
#
# <Run,MPos:-2.860,0.000,0.000>
# ok
#
# <Run,MPos:-3.560,0.000,0.000>
# ok
#
# <Run,MPos:-4.300,0.000,0.000>
# ok
#
# <Run,MPos:-5.020,0.000,0.000>
# ok
#
# <Run,MPos:-5.800,0.000,0.000>
# ok
#
# <Run,MPos:-6.720,0.000,0.000>
# ok
#
# <Run,MPos:-7.540,0.000,0.000>
# ok
#
# <Run,MPos:-8.380,0.000,0.000>
# ok
#
# <Run,MPos:-9.280,0.000,0.000>
# ok
#
# <Run,MPos:-10.020,0.000,0.000>
# ok
#
# <Run,MPos:-10.740,0.000,0.000>
# ok
#
# <Run,MPos:-11.500,0.000,0.000>
# ok
#
# <Run,MPos:-12.120,0.000,0.000>
# ok
#
# <Run,MPos:-12.900,0.000,0.000>
# ok
#
# <Run,MPos:-13.560,0.000,0.000>
# ok
#
# <Run,MPos:-14.320,0.000,0.000>
# ok
#
# <Run,MPos:-15.020,0.000,0.000>
# ok
#
# <Run,MPos:-15.820,0.000,0.000>
# ok
#
# <Run,MPos:-16.480,0.000,0.000>
# ok
#
# <Run,MPos:-17.240,0.000,0.000>
# ok
#
# <Run,MPos:-18.060,0.000,0.000>
# ok
#
# <Run,MPos:-18.800,0.000,0.000>
# ok
#
# <Run,MPos:-19.640,0.000,0.000>
# ok
#
# <Run,MPos:-20.420,0.000,0.000>
# ok
#
# <Run,MPos:-21.200,0.000,0.000>
# ok
#
# <Run,MPos:-21.960,0.000,0.000>
# ok
#
# <Run,MPos:-22.720,0.000,0.000>
# ok
#
# <Run,MPos:-23.440,0.000,0.000>
# ok
#
# <Run,MPos:-24.180,0.000,0.000>
# ok
#
# <Run,MPos:-24.900,0.000,0.000>
# ok
#
# <Run,MPos:-25.780,0.000,0.000>
# ok
#
# <Run,MPos:-26.800,0.000,0.000>
# ok
#
# <Run,MPos:-27.440,0.000,0.000>
# ok
#
# <Run,MPos:-28.200,0.000,0.000>
# ok
#
# <Run,MPos:-28.880,0.000,0.000>
# ok
#
# <Run,MPos:-29.560,0.000,0.000>
# ok
#
# <Run,MPos:-30.360,0.000,0.000>
# ok
#
# <Run,MPos:-31.120,0.000,0.000>
# ok
#
# <Run,MPos:-31.860,0.000,0.000>
# ok
#
# <Run,MPos:-32.680,0.000,0.000>
# ok
#
# <Run,MPos:-33.600,0.000,0.000>
# ok
#
# <Run,MPos:-34.400,0.000,0.000>
# ok
#
# <Run,MPos:-35.000,0.000,0.000>
# ok
#
# <Idle,MPos:-35.000,0.000,0.000>
# ok
#
# ok
#
# <Run,MPos:-34.480,0.000,0.000>
# ok
#
# <Run,MPos:-33.760,0.000,0.000>
# ok
#
# <Run,MPos:-33.100,0.000,0.000>
# ok
#
# <Run,MPos:-32.360,0.000,0.000>
# ok
#
# <Run,MPos:-31.680,0.000,0.000>
# ok
#
# <Run,MPos:-30.920,0.000,0.000>
# ok
#
# <Run,MPos:-30.240,0.000,0.000>
# ok
#
# <Run,MPos:-29.440,0.000,0.000>
# ok
#
# <Run,MPos:-28.780,0.000,0.000>
# ok
#
# <Run,MPos:-28.020,0.000,0.000>
# ok
#
# <Run,MPos:-27.360,0.000,0.000>
# ok
#
# <Run,MPos:-26.580,0.000,0.000>
# ok
#
# <Run,MPos:-25.880,0.000,0.000>
# ok
#
# <Run,MPos:-25.120,0.000,0.000>
# ok
#
# <Run,MPos:-24.480,0.000,0.000>
# ok
#
# <Run,MPos:-23.700,0.000,0.000>
# ok
#
# <Run,MPos:-23.020,0.000,0.000>
# ok
#
# <Run,MPos:-22.240,0.000,0.000>
# ok
#
# <Run,MPos:-21.560,0.000,0.000>
# ok
#
# <Run,MPos:-20.820,0.000,0.000>
# ok
#
# <Run,MPos:-20.140,0.000,0.000>
# ok
#
# <Run,MPos:-19.360,0.000,0.000>
# ok
#
# <Run,MPos:-18.680,0.000,0.000>
# ok
#
# <Run,MPos:-17.920,0.000,0.000>
# ok
#
# <Run,MPos:-17.260,0.000,0.000>
# ok
#
# <Run,MPos:-16.480,0.000,0.000>
# ok
#
# <Run,MPos:-15.800,0.000,0.000>
# ok
#
# <Run,MPos:-15.020,0.000,0.000>
# ok
#
# <Run,MPos:-14.360,0.000,0.000>
# ok
#
# <Run,MPos:-13.580,0.000,0.000>
# ok
#
# <Run,MPos:-12.900,0.000,0.000>
# ok
#
# <Run,MPos:-12.140,0.000,0.000>
# ok
#
# <Run,MPos:-11.440,0.000,0.000>
# ok
#
# <Run,MPos:-10.700,0.000,0.000>
# ok
#
# <Run,MPos:-10.040,0.000,0.000>
# ok
#
# <Run,MPos:-9.260,0.000,0.000>
# ok
#
# <Run,MPos:-8.580,0.000,0.000>
# ok
#
# <Run,MPos:-7.800,0.000,0.000>
# ok
#
# <Run,MPos:-7.120,0.000,0.000>
# ok
#
# <Run,MPos:-6.320,0.000,0.000>
# ok
#
# <Run,MPos:-5.660,0.000,0.000>
# ok
#
# <Run,MPos:-4.960,0.000,0.000>
# ok
#
# <Run,MPos:-4.220,0.000,0.000>
# ok
#
# <Run,MPos:-3.480,0.000,0.000>
# ok
#
# <Run,MPos:-2.800,0.000,0.000>
# ok
#
# <Run,MPos:-2.040,0.000,0.000>
# ok
#
# <Run,MPos:-1.340,0.000,0.000>
# ok
#
# <Run,MPos:-0.540,0.000,0.000>
# ok
#
# <Run,MPos:-0.020,0.000,0.000>
# ok
#
# <Idle,MPos:0.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:0.000,0.000,0.000>
# ok
#
# MESSAGE: 'X:684.10 Y:567.12 Z:5050.15 E:0.00 Count X:54728 Y:45370 Z:404012\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %% [markdown]
# # Testing 20 uL pipette
#
# Returned tip properly

# %%
a.get_tool(ar, type="pipettor", subtype="single", volume=20)
# Out:
# MESSAGE: 'X:0.00 Y:0.0'
# MESSAGE: '0 Z:10.00 E:0.00 Count X:0 Y:0 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: proc'
# MESSAGE: 'essing\n'
# MESSAGE: 'echo:busy: pr'
# MESSAGE: 'ocessing\n'
# MESSAGE: 'echo:busy:'
# MESSAGE: ' processing\n'
# MESSAGE: 'echo:bu'
# MESSAGE: 'sy: processing\n'
# MESSAGE: 'ech'
# MESSAGE: 'o:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processi'
# MESSAGE: 'ng\n'
# MESSAGE: 'echo:busy: proces'
# MESSAGE: 'sing\n'
# MESSAGE: 'X:1383.65 Y:132.45 Z:10.00 E:0.00 Count X:110692 Y:10596 Z:800\nok\n'
# ERROR: Couldn't close the port.
# Msg:
# Grbl Eh Servo 0.9j ['$' for he
# [Caution: Unlocked]
# ok
# ok
# error: Not idle
#
# <Run,MPos:-0.480,0.000,0.000>
# ok
#
# <Run,MPos:-1.200,0.000,0.000>
# ok
#
# <Run,MPos:-1.920,0.000,0.000>
# ok
#
# <Run,MPos:-2.620,0.000,0.000>
# ok
#
# <Run,MPos:-3.320,0.000,0.000>
# ok
#
# <Run,MPos:-4.040,0.000,0.000>
# ok
#
# <Run,MPos:-4.860,0.000,0.000>
# ok
#
# <Idle,MPos:-5.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000>
#
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# <Idle,MPos:-1.000,0.000,0.000>
# ok

# %%
ar.move(z=2000)
a.calibrate_pipettor_tip(robot=ar, x_n=0, y_n=0)
ar.move(z=2000)
a.pickup_tip(robot=ar, x_n=4, y_n=2, well_x_n=0, well_y_n=3)
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:'
# MESSAGE: 'busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:1279.07 Y:567.8'
# MESSAGE: '5 Z:10.00 E:0.00 Count X:102326 Y:45428 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4117.25 E:0.00 Count X:15188 Y:10392 Z:329380\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4162.25 E:0.00 Count X:15188 Y:10392 Z:332980\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4207.25 E:0.00 Count X:15188 Y:10392 Z:336580\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4252.25 E:0.00 Count X:15188 Y:10392 Z:340180\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4297.25 E:0.00 Count X:15188 Y:10392 Z:343780\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4342.25 E:0.00 Count X:15188 Y:10392 Z:347380\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4387.25 E:0.00 Count X:15188 Y:10392 Z:350980\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4432.25 E:0.00 Count X:15188 Y:10392 Z:354580\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4477.25 E:0.00 Count X:15188 Y:10392 Z:358180\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4522.25 E:0.00 Count X:15188 Y:10392 Z:361780\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4567.25 E:0.00 Count X:15188 Y:10392 Z:365380\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4612.25 E:0.00 Count X:15188 Y:10392 Z:368980\nok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4612.25 E:0.00 Count X:15188 Y:10392 Z:368980\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4607.25 E:0.00 Count X:15188 Y:10392 Z:368580\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4602.25 E:0.00 Count X:15188 Y:10392 Z:368180\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4597.25 E:0.00 Count X:15188 Y:10392 Z:367780\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.25 E:0.00 Count X:15188 Y:10392 Z:367380\nok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.25 E:0.00 Count X:15188 Y:10392 Z:367380\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.35 E:0.00 Count X:15188 Y:10392 Z:367388\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.45 E:0.00 Count X:15188 Y:10392 Z:367396\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.55 E:0.00 Count X:15188 Y:10392 Z:367404\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.65 E:0.00 Count X:15188 Y:10392 Z:367412\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.75 E:0.00 Count X:15188 Y:10392 Z:367420\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.85 E:0.00 Count X:15188 Y:10392 Z:367428\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4592.95 E:0.00 Count X:15188 Y:10392 Z:367436\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4593.05 E:0.00 Count X:15188 Y:10392 Z:367444\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4593.15 E:0.00 Count X:15188 Y:10392 Z:367452\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4593.25 E:0.00 Count X:15188 Y:10392 Z:367460\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4593.35 E:0.00 Count X:15188 Y:10392 Z:367468\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4593.45 E:0.00 Count X:15188 Y:10392 Z:367476\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4593.55 E:0.00 Count X:15188 Y:10392 Z:367484\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:4593.65 E:0.00 Count X:15188 Y:10392 Z:367492\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:129.90 Z:
Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:152.84 Z:4647.83 E:0.00 Count X:15188 Y:12227 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:152.74 Z:4647.83 E:0.00 Count X:15188 Y:12219 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:152.64 Z:4647.83 E:0.00 Count X:15188 Y:12211 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:152.54 Z:4647.83 E:0.00 Count X:15188 Y:12203 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:152.44 Z:4647.83 E:0.00 Count X:15188 Y:12195 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:152.34 Z:4647.83 E:0.00 Count X:15188 Y:12187 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:152.24 Z:4647.83 E:0.00 Count X:15188 Y:12179 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:152.14 Z:4647.83 E:0.00 Count X:15188 Y:12171 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:152.04 Z:4647.83 E:0.00 Count X:15188 Y:12163 Z:371826\nok\n'
# MESSAGE: 'X:189.85 Y:152.04 Z:4647.83 E:0.00 Count X:15188 Y:12163 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'X:189.85 Y:129.90 Z:4547.08 E:0.00 Count X:15188 Y:10392 Z:363766\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:90.56 Z:4647.83 E:0.00 Count X:15188 Y:7245 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:100.56 Z:4647.83 E:0.00 Count X:15188 Y:8045 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:110.56 Z:4647.83 E:0.00 Count X:15188 Y:8845 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:120.56 Z:4647.83 E:0.00 Count X:15188 Y:9645 Z:371826\nok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:120.56 Z:4647.83 E:0.00 Count X:15188 Y:9645 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:119.56 Z:4647.83 E:0.00 Count X:15188 Y:9565 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:118.56 Z:4647.83 E:0.00 Count X:15188 Y:9485 Z:371826\nok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:118.56 Z:4647.83 E:0.00 Count X:15188 Y:9485 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:118.66 Z:4647.83 E:0.00 Count X:15188 Y:9493 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:118.76 Z:4647.83 E:0.00 Count X:15188 Y:9501 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:118.86 Z:4647.83 E:0.00 Count X:15188 Y:9509 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:118.96 Z:4647.83 E:0.00 Count X:15188 Y:9517 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:119.06 Z:4647.83 E:0.00 Count X:15188 Y:9525 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:119.16 Z:4647.83 E:0.00 Count X:15188 Y:9533 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:119.26 Z:4647.83 E:0.00 Count X:15188 Y:9541 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:119.36 Z:4647.83 E:0.00 Count X:15188 Y:9549 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:119.46 Z:4647.83 E:0.00 Count X:15188 Y:9557 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:119.56 Z:4647.83 E:0.00 Count X:15188 Y:9565 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 0
#
# MESSAGE: 'X:189.85 Y:119.66 Z:4647.83 E:0.00 Count X:15188 Y:9573 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# Stationary touch probe response: 1
#
# MESSAGE: 'X:189.85 Y:119.76 Z:4647.83 E:0.00 Count X:15188 Y:9581 Z:371826\nok\n'
# MESSAGE: 'X:189.85 Y:119.76 Z:4647.83 E:0.00 Count X:15188 Y:9581 Z:371826\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'X:1278.17 Y:567.40 Z:5313.15 E:0.00 Count X:102254 Y:45392 Z:425052\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
a.return_tip(robot=ar, x_n=4, y_n=2, well_x_n=0, well_y_n=3)
# returned properly
# Out:
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# ok
#
# <Idle,MPos:0.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# ok
#
# <Run,MPos:-1.440,0.000,0.000>
# ok
#
# <Run,MPos:-2.180,0.000,0.000>
# ok
#
# <Run,MPos:-2.860,0.000,0.000>
# ok
#
# <Run,MPos:-3.820,0.000,0.000>
# ok
#
# <Run,MPos:-4.820,0.000,0.000>
# ok
#
# <Run,MPos:-5.580,0.000,0.000>
# ok
#
# <Run,MPos:-6.280,0.000,0.000>
# ok
#
# <Run,MPos:-7.060,0.000,0.000>
# ok
#
# <Run,MPos:-7.840,0.000,0.000>
# ok
#
# <Run,MPos:-8.740,0.000,0.000>
# ok
#
# <Run,MPos:-9.380,0.000,0.000>
# ok
#
# <Run,MPos:-10.260,0.000,0.000>
# ok
#
# <Run,MPos:-11.220,0.000,0.000>
# ok
#
# <Run,MPos:-12.120,0.000,0.000>
# ok
#
# <Run,MPos:-13.040,0.000,0.000>
# ok
#
# <Run,MPos:-13.980,0.000,0.000>
# ok
#
# <Run,MPos:-14.580,0.000,0.000>
# ok
#
# <Run,MPos:-15.380,0.000,0.000>
# ok
#
# <Run,MPos:-16.060,0.000,0.000>
# ok
#
# <Run,MPos:-16.920,0.000,0.000>
# ok
#
# <Run,MPos:-17.960,0.000,0.000>
# ok
#
# <Run,MPos:-18.820,0.000,0.000>
# ok
#
# <Run,MPos:-19.760,0.000,0.000>
# ok
#
# <Run,MPos:-20.460,0.000,0.000>
# ok
#
# <Run,MPos:-21.180,0.000,0.000>
# ok
#
# <Run,MPos:-22.080,0.000,0.000>
# ok
#
# <Run,MPos:-22.720,0.000,0.000>
# ok
#
# <Run,MPos:-23.580,0.000,0.000>
# ok
#
# <Run,MPos:-24.520,0.000,0.000>
# ok
#
# <Run,MPos:-25.420,0.000,0.000>
# ok
#
# <Run,MPos:-26.020,0.000,0.000>
# ok
#
# <Run,MPos:-26.820,0.000,0.000>
# ok
#
# <Run,MPos:-27.500,0.000,0.000>
# ok
#
# <Run,MPos:-28.340,0.000,0.000>
# ok
#
# <Run,MPos:-29.060,0.000,0.000>
# ok
#
# <Run,MPos:-29.820,0.000,0.000>
# ok
#
# <Run,MPos:-30.480,0.000,0.000>
# ok
#
# <Run,MPos:-31.280,0.000,0.000>
# ok
#
# <Run,MPos:-31.960,0.000,0.000>
# ok
#
# <Run,MPos:-32.780,0.000,0.000>
# ok
#
# <Run,MPos:-33.700,0.000,0.000>
# ok
#
# <Run,MPos:-34.480,0.000,0.000>
# ok
#
# <Run,MPos:-35.000,0.000,0.000>
# ok
#
# <Idle,MPos:-35.000,0.000,0.000>
# ok
#
# ok
#
# <Run,MPos:-34.480,0.000,0.000>
# ok
#
# <Run,MPos:-33.740,0.000,0.000>
# ok
#
# <Run,MPos:-33.080,0.000,0.000>
# ok
#
# <Run,MPos:-32.340,0.000,0.000>
# ok
#
# <Run,MPos:-31.660,0.000,0.000>
# ok
#
# <Run,MPos:-30.920,0.000,0.000>
# ok
#
# <Run,MPos:-30.240,0.000,0.000>
# ok
#
# <Run,MPos:-29.480,0.000,0.000>
# ok
#
# <Run,MPos:-28.800,0.000,0.000>
# ok
#
# <Run,MPos:-28.020,0.000,0.000>
# ok
#
# <Run,MPos:-27.360,0.000,0.000>
# ok
#
# <Run,MPos:-26.580,0.000,0.000>
# ok
#
# <Run,MPos:-25.900,0.000,0.000>
# ok
#
# <Run,MPos:-25.140,0.000,0.000>
# ok
#
# <Run,MPos:-24.460,0.000,0.000>
# ok
#
# <Run,MPos:-23.680,0.000,0.000>
# ok
#
# <Run,MPos:-23.020,0.000,0.000>
# ok
#
# <Run,MPos:-22.240,0.000,0.000>
# ok
#
# <Run,MPos:-21.580,0.000,0.000>
# ok
#
# <Run,MPos:-20.800,0.000,0.000>
# ok
#
# <Run,MPos:-20.080,0.000,0.000>
# ok
#
# <Run,MPos:-19.300,0.000,0.000>
# ok
#
# <Run,MPos:-18.640,0.000,0.000>
# ok
#
# <Run,MPos:-17.920,0.000,0.000>
# ok
#
# <Run,MPos:-17.240,0.000,0.000>
# ok
#
# <Run,MPos:-16.460,0.000,0.000>
# ok
#
# <Run,MPos:-15.800,0.000,0.000>
# ok
#
# <Run,MPos:-15.020,0.000,0.000>
# ok
#
# <Run,MPos:-14.360,0.000,0.000>
# ok
#
# <Run,MPos:-13.580,0.000,0.000>
# ok
#
# <Run,MPos:-12.900,0.000,0.000>
# ok
#
# <Run,MPos:-12.140,0.000,0.000>
# ok
#
# <Run,MPos:-11.460,0.000,0.000>
# ok
#
# <Run,MPos:-10.700,0.000,0.000>
# ok
#
# <Run,MPos:-10.020,0.000,0.000>
# ok
#
# <Run,MPos:-9.240,0.000,0.000>
# ok
#
# <Run,MPos:-8.580,0.000,0.000>
# ok
#
# <Run,MPos:-7.800,0.000,0.000>
# ok
#
# <Run,MPos:-7.140,0.000,0.000>
# ok
#
# <Run,MPos:-6.360,0.000,0.000>
# ok
#
# <Run,MPos:-5.680,0.000,0.000>
# ok
#
# <Run,MPos:-4.900,0.000,0.000>
# ok
#
# <Run,MPos:-4.240,0.000,0.000>
# ok
#
# <Run,MPos:-3.460,0.000,0.000>
# ok
#
# <Run,MPos:-2.800,0.000,0.000>
# ok
#
# <Run,MPos:-2.080,0.000,0.000>
# ok
#
# <Run,MPos:-1.340,0.000,0.000>
# ok
#
# <Run,MPos:-0.560,0.000,0.000>
# ok
#
# <Run,MPos:-0.020,0.000,0.000>
# ok
#
# <Idle,MPos:0.000,0.000,0.000>
# ok
#
# ok
#
# <Idle,MPos:0.000,0.000,0.000>
# ok
#
# MESSAGE: 'X:1278.17 Y:567.40 Z:5111.65 E:0.00 Count X:102254 Y:45392 Z:408932\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'

# %%
ar.return_tool()
# Out:
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Home,MPos:-1.000,0.000,0.000>
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
#
# <Idle,MPos:-1.000,0.000,0.000>
# ok
#
# MESSAGE: 'X:1383.65 Y:132.45 Z:10.00 E:0.00 Count X:110692 Y:10596 Z:800\nok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'ok\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'e'
# MESSAGE: 'cho:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'echo:busy: processing\n'
# MESSAGE: 'X:1383.6'
# MESSAGE: '5 Y:132.45 Z:10.00 E:0.00 Count X:110692 Y:10596 Z:800\nok\n'

# %%
ar.openTool()
